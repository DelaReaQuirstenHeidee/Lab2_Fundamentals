# %%
target_name = "Dela Rea"
SEED_NUM = "1"
redacted_name = ""

for char in target_name:
    if char in "AEIOUaeiou":
        redacted_name += SEED_NUM
    else:
        redacted_name += char

print(f"Execution Log: Processing {target_name}...")
print(f"Redacted Output: {redacted_name}")
# Out:
# Execution Log: Processing Dela Rea...
# Redacted Output: D1l1 R11

# %%
first_letter = "Q"
ASCII_val = ord(first_letter)
seed_num = 2
loops = 5

verification_hash = (ASCII_val + seed_num) - loops

print(f"ASCII; {ASCII_val}, Hash: {verification_hash}")
# Out:
# ASCII; 81, Hash: 78

# %%
correct_password = "HAEDEN03"
attempts = 3
user_input = ""

while user_input != correct_password and attempts > 0:
    user_input = input("Enter Password: ")
    attempts += 3
    print(f"Attempt {attempts} You entered '{user_input}'")

    print(f"Access Granted in {attempts} attempts.")
# Out:
# Attempt 6 You entered 'hello'
# Access Granted in 6 attempts.
# Attempt 9 You entered 'you'
# Access Granted in 9 attempts.
# Attempt 12 You entered 'what'
# Access Granted in 12 attempts.
# Attempt 15 You entered 'it'
# Access Granted in 15 attempts.
# Attempt 18 You entered 'no'
# Access Granted in 18 attempts.
# Attempt 21 You entered 'HAEDEN03'
# Access Granted in 21 attempts.
